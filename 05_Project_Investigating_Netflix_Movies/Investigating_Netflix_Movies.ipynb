# %% [markdown]
# # Problem Statement
# We need to perform exploratory data analysis on the netflix_data.csv data to understand more about movies from the 1990s decade.
#
# Ideally we need to answer two important questions.
#
# > What was the most frequent movie duration in the 1990s? Save an approximate answer as an integer called duration (use 1990 as the decade's start year).
#
# > A movie is considered short if it is less than 90 minutes. Count the number of short action movies released in the 1990s and save this integer as short_movie_count.

# %% [markdown]
# # Importing Relevant DS Libraries and Loading DataSet in DataFrame

# %% [markdown]
# Let us import the relevant DS Libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Saving the Raw Link of Data Set in the variable "file_path"

# %%
file_path = "https://raw.githubusercontent.com/HarisJafri-xcode/Data-Analyst-in-Python/refs/heads/main/05_Project_Investigating_Netflix_Movies/netflix_data.csv"

# %% [markdown]
# Loading the Data Set as Pandas DataFrame and viewing the first 3 Rows of the DataFrame for observation.

# %%
df = pd.read_csv(file_path)
df.head(3)
# Out:
#    index show_id   type  title           director  \
# 0      0      s2  Movie   7:19  Jorge Michel Grau
# 1      1      s3  Movie  23:59       Gilbert Chan
# 2      2      s4  Movie      9        Shane Acker
#
#                                                 cast        country  \
# 0  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 1  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 2  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#           date_added  release_year  duration  \
# 0  December 23, 2016          2016        93
# 1  December 20, 2018          2011        78
# 2  November 16, 2017          2009        80
#
#                                          description          genre
# 0  After a devastating earthquake hits Mexico Cit...         Dramas
# 1  When an army recruit is found dead, his fellow...  Horror Movies
# 2  In a postapocalyptic world, rag-doll robots hi...         Action

# %% [markdown]
# # Solution

# %%
# Subsetting the DataFrame for the type "Movie"

movie_mask = df["type"] == "Movie"

df_movie = df[movie_mask]

df_movie.head(3)
# Out:
#    index show_id   type  title           director  \
# 0      0      s2  Movie   7:19  Jorge Michel Grau
# 1      1      s3  Movie  23:59       Gilbert Chan
# 2      2      s4  Movie      9        Shane Acker
#
#                                                 cast        country  \
# 0  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 1  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 2  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#           date_added  release_year  duration  \
# 0  December 23, 2016          2016        93
# 1  December 20, 2018          2011        78
# 2  November 16, 2017          2009        80
#
#                                          description          genre
# 0  After a devastating earthquake hits Mexico Cit...         Dramas
# 1  When an army recruit is found dead, his fellow...  Horror Movies
# 2  In a postapocalyptic world, rag-doll robots hi...         Action

# %%
# Keeping only the movies in 90s Era

movie_90s_mask = (df_movie["release_year"] >= 1990) & (df_movie["release_year"] < 2000)

df_movie_90s = df_movie[movie_90s_mask]

df_movie_90s.head(3)
# Out:
#      index show_id   type                   title            director  \
# 6        6      s8  Movie                     187      Kevin Reynolds
# 118    118    s167  Movie       A Dangerous Woman  Stephen Gyllenhaal
# 145    145    s211  Movie  A Night at the Roxbury    John Fortenberry
#
#                                                   cast        country  \
# 6    Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
# 118  Debra Winger, Barbara Hershey, Gabriel Byrne, ...  United States
# 145  Will Ferrell, Chris Kattan, Dan Hedaya, Molly ...  United States
#
#            date_added  release_year  duration  \
# 6    November 1, 2019          1997       119
# 118     April 1, 2018          1993       101
# 145  December 1, 2019          1998        82
#
#                                            description     genre
# 6    After one of his high school students attacks ...    Dramas
# 118  At the center of this engrossing melodrama is ...    Dramas
# ...

# %%
# Viewing the distribution of movies duration released in 90s Era
plt.hist(df_movie_90s["duration"])
plt.title('Distribution of Movie Durations in the 1990s')
plt.xlabel('Duration (minutes)')
plt.ylabel('Number of Movies')
plt.show()

# %%
duration = 100

# %% [markdown]
# From Histogram, it is quite clear that 100 minutes is the most frequent duration of the Movies released in the 90s Era.

# %% [markdown]
# Now we need to find number of Short Action Movies in the 90s Era. A Movie is considered short if it is less than 90 minutes.

# %%
# Filter out 90s Movie with Action genre
df_movie_90s_action = df_movie_90s[df_movie_90s["genre"] == "Action"]

# %%
# Constructing a mask for movies with duration less than 90 minutes
short_movie_mask = df_movie_90s_action["duration"] < 90

# %%
# Applying the mask to filter the DataFrame
df_movie_90s_action_short = df_movie_90s_action[short_movie_mask]

# %%
# Counting the number of movies in the filtered DataFrame
short_movie_count = df_movie_90s_action_short["duration"].count()
print(short_movie_count)
# Out:
# 7

# %% [markdown]
# There are 7 Movies in the Action Genre that can be considered as Short Movie.
