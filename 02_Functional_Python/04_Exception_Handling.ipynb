# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HarisJafri-xcode/Data-Analyst-in-Python/blob/main/02_Functional_Python/04_Exception_Handling.ipynb)

# %% [markdown]
# # Exception Handling in Python
#
# Exceptions are runtime errors that interrupt the normal flow of a program.
#
# Here we cover:
# - What exceptions are
# - Basic `try` / `except`
# - `else` and `finally`
# - Combined pattern
# - Practice

# %% [markdown]
# ## 1. What is an Exception?
#
# An **exception** is an event that occurs during execution and disrupts the normal flow.
#
# Example errors:
# - `ZeroDivisionError`
# - `TypeError`
# - `ValueError`

# %%
num1 = 7
num2 = 0

# Uncomment to see ZeroDivisionError
# print(num1 / num2)

# %%
# Uncomment to see TypeError
# print("7" + 4)

# %% [markdown]
# If an exception is not handled, the program stops.
#
# To handle exceptions, use `try` / `except`.

# %% [markdown]
# ## 2. Basic try / except
#
# Structure:
# ```python
# try:
#     # risky code
# except:
#     # fallback when any exception occurs
# ```

# %%
try:
    num1 = 7
    num0 = 0
    print(num1 / num0)
except:
    print("Someone divided by 0")
# Out:
# Someone divided by 0

# %%
try:
    var = 10
    print(10 / 2)
except:
    print("OMG, Error!")

print("Finished")
# Out:
# 5.0
# Finished

# %% [markdown]
# ## 3. try / except with Input
#
# We can handle invalid user input using exception handling.

# %%
try:
    age = int(input("Enter Your Age: "))
    print("You will be", age + 2, "after 2 Years.")
except:
    print("Please Enter a Whole Number")

print("Finished")
# Out:
# Enter Your Age: 25
# You will be 27 after 2 Years.
# Finished

# %% [markdown]
# ## 4. finally – Always Runs
#
# The `finally` block runs no matter what happens (error or no error).

# %%
try:
    print(1)
except:
    print(2)
finally:
    print(3)
# Out:
# 1
# 3

# %% [markdown]
# ## 5. else – Runs Only if No Error
#
# `else` executes only when the `try` block has **no exception**.

# %%
try:
    print(1)
except:
    print(2)
else:
    print(3)
# Out:
# 1
# 3

# %%
try:
    print(1 / 0)
except:
    print(4)
else:
    print(5)
# Out:
# 4

# %% [markdown]
# ## 6. Full Pattern: try + except + else + finally
#
# Full structure:
# ```python
# try:
#     # risky code
# except SomeError:
#     # handle specific error
# else:
#     # runs only if no error
# finally:
#     # runs always
# ```

# %%
try:
    x = int(input("Enter a number: "))
    print("Square:", x**2)
except ValueError:
    print("That's not a valid integer.")
else:
    print("Success! No errors.")
finally:
    print("This will run no matter what.")
# Out:
# Enter a number: 5
# Square: 25
# Success! No errors.
# This will run no matter what.

# %% [markdown]
# ## 7. Practice
#
# 1. Ask for two numbers and safely divide them with `try` / `except`.
# 2. Catch `ZeroDivisionError` and `ValueError` separately.
# 3. Add a `finally` block that prints `Done` every time.

# %%
# Practice area for exception handling
try:
    a = int(input("Enter numerator: "))
    b = int(input("Enter denominator: "))
    print("Result:", a / b)
except ZeroDivisionError:
    print("Cannot divide by zero.")
except ValueError:
    print("Please enter only integers.")
finally:
    print("Done")
# Out:
# Enter numerator: 15
# Enter denominator: 1
# Result: 15.0
# Done

# %% [markdown]
# ## Summary
#
# - `try` → risky code
# - `except` → plan B when error occurs
# - `else` → runs only if no error
# - `finally` → always runs (cleanup, logging, etc.)
