# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HarisJafri-xcode/Data-Analyst-in-Python/blob/main/04_Data_Manipulation_with_pandas/04_Creating_and_Visualizing_DataFrames.ipynb)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Visualizing your Data

# %%
file_path = 'https://raw.githubusercontent.com/HarisJafri-xcode/Data-Analyst-in-Python/refs/heads/main/04_Data_Manipulation_with_pandas/avocados.pkl'
avocados = pd.read_pickle(file_path)

# %% [markdown]
# Avocados are increasingly popular and delicious in guacamole and on toast. The Hass Avocado Board keeps track of avocado supply and demand across the USA, including the sales of three different sizes of avocado. In this exercise, you'll use a bar plot to figure out which size is the most popular.

# %% [markdown]
# Bar plots are great for revealing relationships between categorical (size) and numeric (number sold) variables, but you'll often have to manipulate your data first in order to get the numbers you need for plotting.

# %%
# First Few Rows of the DataFrame
avocados.head()
# Out:
#          date          type  year  avg_price   size     nb_sold
# 0  2015-12-27  conventional  2015       0.95  small  9626901.09
# 1  2015-12-20  conventional  2015       0.98  small  8710021.76
# 2  2015-12-13  conventional  2015       0.93  small  9855053.66
# 3  2015-12-06  conventional  2015       0.89  small  9405464.36
# 4  2015-11-29  conventional  2015       0.99  small  8094803.56

# %% [markdown]
# ### Bar Plot

# %% [markdown]
# For each avocado size group, calculate the total number sold, storing as nb_sold_by_size.

# %%
nb_sold_by_size = avocados.groupby('size')['nb_sold'].sum()

# %%
# Checking the Data Series
nb_sold_by_size
# Out:
# size
# extra_large    1.561752e+08
# large          2.015012e+09
# small          2.054936e+09
# Name: nb_sold, dtype: float64

# %%
# Plotting using Pandas Visualizing Properties
nb_sold_by_size.plot(kind='bar')
plt.show()

# %% [markdown]
# ### Line Plot

# %% [markdown]
# Line plots are designed to visualize the relationship between two numeric variables, where each data values is connected to the next one. They are especially useful for visualizing the change in a number over time since each time point is naturally connected to the next time point. In this exercise, you'll visualize the change in avocado sales over three years.

# %% [markdown]
# Get the total number of avocados sold on each date.

# %%
nb_sold_by_date = avocados.groupby('date')['nb_sold'].sum()

# %%
nb_sold_by_date.plot(kind='line')
plt.show()

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Scatter plots are ideal for visualizing relationships between numerical variables. In this exercise, you'll compare the number of avocados sold to average price and see if they're at all related. If they're related, you may be able to use one number to predict the other.

# %% [markdown]
# Create a scatter plot with nb_sold on the x-axis and avg_price on the y-axis. Title it "Number of avocados sold vs. average price" and then show the plot.

# %%
avocados.plot(kind='scatter',x='nb_sold',y='avg_price',title="Number of avocados sold vs. average price")
plt.show()

# %%
avocados[avocados['type'] == 'conventional']['avg_price'].plot(kind='hist',legend=True)
avocados[avocados['type'] == 'organic']['avg_price'].plot(kind='hist',legend=True)
plt.title('Average Price Frequency')
plt.xlabel('Avg. Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Modify your code to adjust the transparency of both histograms to 0.25 to see how much overlap there is between the two distributions. Also change the colors !

# %%
avocados[avocados['type'] == 'conventional']['avg_price'].plot(kind='hist',legend=True, color='green', alpha=0.25)
avocados[avocados['type'] == 'organic']['avg_price'].plot(kind='hist',legend=True, color='red', alpha=0.25)
plt.title('Average Price Frequency')
plt.xlabel('Avg. Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Modify your code to to use 50 bins in both histograms.

# %%
avocados[avocados['type'] == 'conventional']['avg_price'].plot(kind='hist',legend=True, color='green', alpha=0.25, bins=50)
avocados[avocados['type'] == 'organic']['avg_price'].plot(kind='hist',legend=True, color='red', alpha=0.25, bins=50)
plt.title('Average Price Frequency')
plt.xlabel('Avg. Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Finding Missing Values

# %% [markdown]
# Missing values are everywhere, and you don't want them interfering with your work. Some functions ignore missing data by default, but that's not always the behavior you might want. Some functions can't handle missing values at all, so these values need to be taken care of before you can use them. If you don't know where your missing values are, or if they exist, you could make mistakes in your analysis. In this exercise, you'll determine if there are missing values in the dataset, and if so, how many.

# %%
file_path_2016 = 'https://raw.githubusercontent.com/HarisJafri-xcode/Data-Analyst-in-Python/refs/heads/main/04_Data_Manipulation_with_pandas/avocados_2016.csv'
avocados_2016 = pd.read_csv(file_path_2016)

# %% [markdown]
# Print a DataFrame that shows whether each value in avocados_2016 is missing or not.

# %%
avocados_2016.isna()
# Out:
#      date  avg_price  total_sold  small_sold  large_sold  xl_sold  \
# 0   False      False       False       False       False    False
# 1   False      False       False       False       False    False
# 2   False      False       False       False        True    False
# 3   False      False       False       False       False    False
# 4   False      False       False       False       False     True
# 5   False      False       False        True       False    False
# 6   False      False       False       False       False    False
# 7   False      False       False       False        True    False
# 8   False      False       False       False       False    False
# 9   False      False       False       False       False    False
# 10  False      False       False       False        True    False
# 11  False      False       False       False       False    False
# 12  False      False       False       False       False    False
# ...

# %% [markdown]
# Print a summary that shows whether any value in each column is missing or not.

# %%
avocados_2016.isna().any()
# Out:
# date               False
# avg_price          False
# total_sold         False
# small_sold          True
# large_sold          True
# xl_sold             True
# total_bags_sold    False
# small_bags_sold    False
# large_bags_sold    False
# xl_bags_sold       False
# dtype: bool

# %% [markdown]
# Create a bar plot of the total number of missing values in each column.

# %%
avocados_2016.isna().sum()
# Out:
# date               0
# avg_price          0
# total_sold         0
# small_sold         6
# large_sold         6
# xl_sold            4
# total_bags_sold    0
# small_bags_sold    0
# large_bags_sold    0
# xl_bags_sold       0
# dtype: int64

# %%
avocados_2016.isna().sum().plot(kind='bar')
plt.xlabel('Columns of Data Frame')
plt.ylabel('No. of Missing Values')
plt.title('No. of Missing Values in DataFrame')
plt.show()

# %% [markdown]
# # Removing Missing Values

# %% [markdown]
# Remove the rows of avocados_2016 that contain missing values and store the remaining rows in avocados_complete.

# %%
avocados_complete = avocados_2016.dropna()

# %% [markdown]
# Verify that all missing values have been removed from avocados_complete. Calculate each column that has NAs and print.

# %%
avocados_complete.isnull().sum()
# Out:
# date               0
# avg_price          0
# total_sold         0
# small_sold         0
# large_sold         0
# xl_sold            0
# total_bags_sold    0
# small_bags_sold    0
# large_bags_sold    0
# xl_bags_sold       0
# dtype: int64

# %% [markdown]
# # Replacing Missing Values

# %% [markdown]
# Another way of handling missing values is to replace them all with the same value. For numerical variables, one option is to replace values with 0— you'll do this here. However, when you replace missing values, you make assumptions about what a missing value means. In this case, you will assume that a missing number sold means that no sales for that avocado type were made that week.

# %% [markdown]
# Create a list "cols_with_missing", containing the names of columns with missing values: "small_sold", "large_sold", and "xl_sold"

# %%
cols_with_missing = ["small_sold", "large_sold", "xl_sold"]

# %% [markdown]
# Create a histogram of those columns.

# %%
avocados_2016[cols_with_missing].plot(kind='hist',alpha=0.25)
plt.show()

# %% [markdown]
# Replace the missing values of avocados_2016 with 0s and store the result as avocados_filled.

# %%
# Imputing
avocados_filled = avocados_2016.fillna(0)

# Plotting
avocados_filled[cols_with_missing].plot(kind='hist',alpha=0.25)
plt.show()

# %% [markdown]
# # Creating DataFrames with Dictionary of List

# %% [markdown]
# DataFrames can be created with Dictionary of List.

# %%
# Create a dictionary of lists

avocados_dict = {
  "date": ["2019-11-17","2019-12-01"],
  "small_sold": [10859987,9291631],
  "large_sold": [7674135,6238096]
}

# %%
# Convert dictionary into DataFrame
avocados_2019 = pd.DataFrame(avocados_dict)

# %%
avocados_2019
# Out:
#          date  small_sold  large_sold
# 0  2019-11-17    10859987     7674135
# 1  2019-12-01     9291631     6238096

# %% [markdown]
# # CSV to DataFrame and DataFrame to CSV

# %% [markdown]
# You work for an airline, and your manager has asked you to do a competitive analysis and see how often passengers flying on other airlines are involuntarily bumped from their flights. You got a CSV file (airline_bumping.csv) from the Department of Transportation containing data on passengers that were involuntarily denied boarding in 2016 and 2017, but it doesn't have the exact numbers you want. In order to figure this out, you'll need to get the CSV into a pandas DataFrame and do some manipulation!

# %% [markdown]
# Read the CSV file "airline_bumping.csv" and store it as a DataFrame called airline_bumping.
#
# Print the first few rows of airline_bumping.

# %%
# Read CSV as DataFrame called airline_bumping
airline_bumping = pd.read_csv('https://raw.githubusercontent.com/HarisJafri-xcode/Data-Analyst-in-Python/refs/heads/main/04_Data_Manipulation_with_pandas/airline_bumping.csv')

# Take a look at the DataFrame
airline_bumping.head()
# Out:
#              airline  year  nb_bumped  total_passengers
# 0    DELTA AIR LINES  2017        679          99796155
# 1     VIRGIN AMERICA  2017        165           6090029
# 2    JETBLUE AIRWAYS  2017       1475          27255038
# 3    UNITED AIRLINES  2017       2067          70030765
# 4  HAWAIIAN AIRLINES  2017         92           8422734

# %% [markdown]
# For each airline group, select the nb_bumped, and total_passengers columns, and calculate the sum (for both years). Store this as airline_totals.

# %%
airline_totals = airline_bumping.groupby('airline')[['nb_bumped','total_passengers']].sum()

# %% [markdown]
# Create a new column of airline_totals called bumps_per_10k, which is the number of passengers bumped per 10,000 passengers in 2016 and 2017.

# %%
airline_totals["bumps_per_10k"] = (airline_totals['nb_bumped'] / airline_totals['total_passengers']) * 10000

# %% [markdown]
# Sort airline_totals by the values of bumps_per_10k from highest to lowest, storing as airline_totals_sorted.

# %%
airline_totals_sorted = airline_totals.sort_values('bumps_per_10k', ascending=False)

# %%
airline_totals_sorted.head()
# Out:
#                      nb_bumped  total_passengers  bumps_per_10k
# airline
# EXPRESSJET AIRLINES       3326          27858678       1.193883
# SPIRIT AIRLINES           2920          32304571       0.903897
# SOUTHWEST AIRLINES       18585         228142036       0.814624
# JETBLUE AIRWAYS           3615          53245866       0.678926
# SKYWEST AIRLINES          3094          47091737       0.657015

# %% [markdown]
# Save the sorted DataFrame as a CSV called "airline_totals_sorted.csv".

# %%
# airline_totals_sorted.to_csv('airline_totals_sorted.csv')
